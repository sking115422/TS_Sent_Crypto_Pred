# %%
import twint

#To make twint run inside juypter notebook
import nest_asyncio 

nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Search = "covid"

# Run
twint.run.Search(c)
# Out:
# 1462656780044058627 2021-11-22 00:38:45 -0500 <gorkl_official> За последние сутки на Кубани скончались 69 человек с диагнозом COVID-19 Всего в регионе выявили 989 новых случаев коронавируса в 43 муниципалитетах. Из них 9 - в Горячем Ключе.  https://t.co/JNKuYLyKM5 #гкновости #горячийключ #стопкоронавирус #здоровьевприоритете  https://t.co/S5iLLitZ0D
# 1462656778705915904 2021-11-22 00:38:45 -0500 <SanookNews> ศูนย์ข้อมูล COVID-19 รายงานสถานการณ์  วันที่ 22 พ.ย. 64 พบผู้ติดเชื้อรายใหม่ 6,428 ราย จำแนกเป็น ผู้ป่วยจากระบบเฝ้าระวังฯ 5,732 ราย ผู้ป่วยจากการค้นหาเชิงรุก 133 ราย ผู้ป่วยภายในเรือนจำ/ที่ต้องขัง 553 ราย และผู้ป่วยมาจากต่างประเทศ 10 ราย  #โควิด19 #โควิดวันนี้ #SanookNews  https://t.co/NTGnE2FYFs
# ...
